# %% [markdown]
# ### Loading the dependencies

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./athlete_events.csv')

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.size
# Out:
# 4066740

# %%
data.shape
# Out:
# (271116, 15)

# %%
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
data.drop(columns="ID")
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# 0                      A Dijiang   M  24.0   180.0    80.0           China
# 1                       A Lamusi   M  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 271111                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271113                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
data.Team.value_counts()
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Briar                1
# Hannover             1
# Nan-2                1
# Brentina             1
# Digby                1
# Name: Team, Length: 1184, dtype: int64

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.NOC.value_counts()
# Out:
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
#        ...
# YMD        5
# SSD        3
# UNK        2
# NBO        2
# NFL        1
# Name: NOC, Length: 230, dtype: int64

# %%
summer=data[data['Season']=='Summer']
summer
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
winter=data[data['Season']=='Winter']
winter
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %%
data.Sex.value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
data.Medal.unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
data['Gold']=[1 if medal=='Gold' else 0 for medal in data['Medal']]
data['Silver']=[1 if medal=='Silver' else 0 for medal in data['Medal']]
data['Bronze']=[1 if medal =='Bronze' else 0 for medal in data['Medal']]
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal  Gold  Silver  Bronze
# 0       Basketball Men's Basketball   NaN     0       0       0
# ...

# %%
country_wise_medals=data.groupby(['Team'])['Gold','Silver','Bronze'].sum()
country_wise_medals
# Out:
#                        Gold  Silver  Bronze
# Team
# 30. Februar               0       0       0
# A North American Team     0       0       4
# Acipactli                 0       0       0
# Acturus                   0       0       0
# Afghanistan               0       0       2
# ...                     ...     ...     ...
# Zambia                    0       1       1
# Zefyros                   0       0       0
# Zimbabwe                 17       4       1
# Zut                       0       3       0
# rn-2                      0       0       0
#
# [1184 rows x 3 columns]

# %%
 country_wise_medals['Total']=country_wise_medals['Gold']+country_wise_medals['Silver']+country_wise_medals['Bronze']
 country_wise_medals
# Out:
#                        Gold  Silver  Bronze  Total
# Team
# 30. Februar               0       0       0      0
# A North American Team     0       0       4      4
# Acipactli                 0       0       0      0
# Acturus                   0       0       0      0
# Afghanistan               0       0       2      2
# ...                     ...     ...     ...    ...
# Zambia                    0       1       1      2
# Zefyros                   0       0       0      0
# Zimbabwe                 17       4       1     22
# Zut                       0       3       0      3
# rn-2                      0       0       0      0
#
# [1184 rows x 4 columns]

# %%
country_wise_medals.sort_values(by="Total",ascending=False)
# Out:
#                Gold  Silver  Bronze  Total
# Team
# United States  2474    1512    1233   5219
# Soviet Union   1058     716     677   2451
# Germany         679     627     678   1984
# Great Britain   519     582     572   1673
# France          455     518     577   1550
# ...             ...     ...     ...    ...
# Ireland-1         0       0       0      0
# Israel-1          0       0       0      0
# Israel-2          0       0       0      0
# Italy-3           0       0       0      0
# rn-2              0       0       0      0
#
# [1184 rows x 4 columns]

# %%
country_wise_medals.nlargest(1,'Total')
# Out:
#                Gold  Silver  Bronze  Total
# Team
# United States  2474    1512    1233   5219

# %%
no_gold_medal=country_wise_medals[country_wise_medals['Gold']==0]
no_gold_medal
# Out:
#                        Gold  Silver  Bronze  Total
# Team
# 30. Februar               0       0       0      0
# A North American Team     0       0       4      4
# Acipactli                 0       0       0      0
# Acturus                   0       0       0      0
# Afghanistan               0       0       2      2
# ...                     ...     ...     ...    ...
# Yugoslavia-2              0       0       0      0
# Zambia                    0       1       1      2
# Zefyros                   0       0       0      0
# Zut                       0       3       0      3
# rn-2                      0       0       0      0
#
# [942 rows x 4 columns]

# %%
List = list(no_gold_medal.index)
len(List)
# Out:
# 942

# %%
print('number of countries with no gold medal=',len(List))
# Out:
# number of countries with no gold medal= 942

# %%
india=data.query("Gold==0 & Silver==0 & Bronze==0 & NOC=='IND'")
india
# Out:
#             ID                                           Name Sex   Age  \
# 505        281                                 S. Abdul Hamid   M   NaN
# 506        281                                 S. Abdul Hamid   M   NaN
# 895        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 896        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 897        512                Shiny Kurisingal Abraham-Wilson   F  23.0
# ...        ...                                            ...  ..   ...
# 264138  132177                           Mohammad Anas Yahiya   M  21.0
# 264139  132177                           Mohammad Anas Yahiya   M  21.0
# 265876  133029  Thyadathuvilla Chandrapillai "T. C." Yohannan   M  29.0
# 270912  135480                                   Geeta Zutshi   F  23.0
# 270913  135480                                   Geeta Zutshi   F  27.0
#
#         Height  Weight   Team  NOC        Games  Year  Season            City  \
# ...

# %%
cross_tab1=pd.crosstab(index=data.Team,columns=data.Year,values=data.Gold,aggfunc='sum')

# %%
cross_tab1.loc['China']
# Out:
# Year
# 1896     NaN
# 1900     NaN
# 1904     NaN
# 1906     NaN
# 1908     NaN
# 1912     NaN
# 1920     NaN
# 1924     NaN
# 1928     NaN
# 1932     0.0
# 1936     0.0
# 1948     0.0
# 1952     0.0
# 1956     NaN
# 1960     NaN
# 1964     NaN
# 1968     NaN
# 1972     NaN
# 1976     NaN
# 1980     0.0
# 1984    24.0
# 1988     4.0
# 1992    14.0
# 1994     0.0
# 1996    13.0
# 1998     0.0
# 2000    31.0
# 2002     2.0
# 2004    42.0
# 2006     2.0
# 2008    72.0
# 2010     7.0
# 2012    50.0
# 2014     3.0
# 2016    44.0
# Name: China, dtype: float64

# %%
cross_tab1.loc['India']
# Out:
# Year
# 1896     NaN
# 1900     0.0
# 1904     NaN
# 1906     NaN
# 1908     NaN
# 1912     NaN
# 1920     0.0
# 1924     7.0
# 1928    14.0
# 1932    15.0
# 1936    19.0
# 1948    20.0
# 1952    14.0
# 1956    17.0
# 1960     0.0
# 1964    15.0
# 1968     0.0
# 1972     0.0
# 1976     0.0
# 1980    16.0
# 1984     0.0
# 1988     0.0
# 1992     0.0
# 1994     NaN
# 1996     0.0
# 1998     0.0
# 2000     0.0
# 2002     0.0
# 2004     0.0
# 2006     0.0
# 2008     1.0
# 2010     0.0
# 2012     0.0
# 2014     0.0
# 2016     0.0
# Name: India, dtype: float64

# %%
# athlete with most height

data.nlargest(1,'Height')
# Out:
#             ID      Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 265040  132627  Yao Ming   M  20.0   226.0   141.0  China  CHN  2000 Summer
#
#         Year  Season    City       Sport                        Event Medal  \
# 265040  2000  Summer  Sydney  Basketball  Basketball Men's Basketball   NaN
#
#         Gold  Silver  Bronze
# 265040     0       0       0

# %%
data.nlargest(2,'Weight')
# Out:
#           ID               Name Sex   Age  Height  Weight  Team  NOC  \
# 23155  12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM
# 23156  12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM
#
#              Games  Year  Season     City Sport                   Event Medal  \
# 23155  2008 Summer  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 23156  2012 Summer  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN
#
#        Gold  Silver  Bronze
# 23155     0       0       0
# 23156     0       0       0

# %%
# eldest athlete 
data.nlargest(1,'Age')
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal  \
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN
#
#         Gold  Silver  Bronze
# 257054     0       0       0

# %%
#youngest athlete
data.nsmallest(1,'Age')
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal  Gold  \
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze     0
#
#         Silver  Bronze
# 142882       0       1

# %%
# countries without female athlete
gender_count=pd.crosstab(data.Sex,data.NOC)

# %%
gender_count
# Out:
# NOC  AFG  AHO  ALB  ALG  AND  ANG  ANT  ANZ   ARG  ARM  ...  VIE  VIN  VNM  \
# Sex                                                     ...
# F      5   12   27   94   42  129   37    2   643   38  ...   74   11    2
# M    121   67   43  457  127  138   96   84  2654  183  ...   80   31   60
#
# NOC  WIF  YAR  YEM  YMD   YUG  ZAM  ZIM
# Sex
# F      0    0    4    0   378   19  113
# M     20   11   28    5  2205  164  198
#
# [2 rows x 230 columns]

# %%
gender_count1=gender_count.unstack().unstack()
gender_count1
# Out:
# Sex    F     M
# NOC
# AFG    5   121
# AHO   12    67
# ALB   27    43
# ALG   94   457
# AND   42   127
# ..   ...   ...
# YEM    4    28
# YMD    0     5
# YUG  378  2205
# ZAM   19   164
# ZIM  113   198
#
# [230 rows x 2 columns]

# %%
countries_without_female=gender_count1[gender_count1['F']==0]
countries_without_female
# Out:
# Sex  F    M
# NOC
# CRT  0   11
# NBO  0    2
# NFL  0    1
# UAR  0  123
# UNK  0    2
# WIF  0   20
# YAR  0   11
# YMD  0    5

# %%
# country that won gold medal in basketball in the year 1992

# %%
data.query("Year==1992 & Sport== 'Basketball' & Medal=='Gold' & Sex=='M'")
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 14656     7901             Charles Wade Barkley   M  29.0   198.0   114.0
# 22150    11668                   Larry Joe Bird   M  35.0   205.0   100.0
# 58646    30009             Clyde Austin Drexler   M  30.0   200.0   101.0
# 65566    33553           Patrick Aloysius Ewing   M  29.0   213.0   109.0
# 109625   55424      Earvin "Magic" Johnson, Jr.   M  32.0   205.0   100.0
# 110517   55881           Michael Jeffrey Jordan   M  29.0   198.0    90.0
# 130713   65809        Christian Donald Laettner   M  22.0   211.0   107.0
# 147819   74176                      Karl Malone   M  29.0   205.0   116.0
# 165616   83179  Christopher Paul "Chris" Mullin   M  28.0   200.0    98.0
# 189367   95105           Scottie Maurice Pippen   M  26.0   200.0   102.0
# 201956  101428           David Maurice Robinson   M  26.0   216.0   107.0
# 229678  115325            John Houston Stockton   M  30.0   185.0    79.0
#
# ...

# %%
# age category wise medal count

# %%
age_category_medal_count=data.groupby(['Medal'])['Age'].value_counts()

# %%
age_category_medal_count
# Out:
# Medal   Age
# Bronze  23.0    1116
#         24.0    1106
#         22.0    1081
#         25.0    1045
#         26.0    1001
#                 ...
# Silver  57.0       1
#         69.0       1
#         71.0       1
#         72.0       1
#         73.0       1
# Name: Age, Length: 165, dtype: int64

# %%
age_category_medal_count.unstack().unstack().unstack()
# Out:
# Medal  Bronze  Gold  Silver
# Age
# 10.0      1.0   NaN     NaN
# 11.0      NaN   NaN     1.0
# 12.0      3.0   NaN     3.0
# 13.0      2.0   7.0     7.0
# 14.0     18.0  27.0    30.0
# ...       ...   ...     ...
# 68.0      NaN   NaN     2.0
# 69.0      1.0   NaN     1.0
# 71.0      1.0   NaN     1.0
# 72.0      1.0   NaN     1.0
# 73.0      NaN   NaN     1.0
#
# [61 rows x 3 columns]

# %%
#oldest gold medalist

# %%
gold=data.query("Medal=='Gold'")

# %%
gold_oldest=gold[gold['Age']==gold.Age.max()]

# %%
gold_oldest
# Out:
#             ID               Name Sex   Age  Height  Weight           Team  \
# 105199   53238    Charles Jacobus   M  64.0     NaN     NaN  United States
# 233390  117046  Oscar Gomer Swahn   M  64.0     NaN     NaN         Sweden
#
#         NOC        Games  Year  Season       City     Sport  \
# 105199  USA  1904 Summer  1904  Summer  St. Louis     Roque
# 233390  SWE  1912 Summer  1912  Summer  Stockholm  Shooting
#
#                                                    Event Medal  Gold  Silver  \
# 105199                               Roque Men's Singles  Gold     1       0
# 233390  Shooting Men's Running Target, Single Shot, Team  Gold     1       0
#
#         Bronze
# 105199       0
# 233390       0
