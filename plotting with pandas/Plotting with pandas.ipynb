# %% [markdown]
# # PLOTTING WITH PANDAS

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Car_sales (1).csv')
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
data.rename(columns = { "__year_resale_value":"year_resale_value"} , inplace = True)
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919             16.360    Passenger
# 1        Acura       TL              39.384             19.875    Passenger
# 3        Acura       RL               8.588             29.725    Passenger
# 4         Audi       A4              20.397             22.255    Passenger
# 5         Audi       A6              18.780             23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.Horsepower.plot.hist();

# %%
data.Horsepower.plot.hist(figsize=(6,3),cmap='CMRmap');

# %%
data.Sales_in_thousands.plot.box()
# Out:
# <AxesSubplot:>

# %%
data.Sales_in_thousands.plot.box(figsize=(6,3),cmap='Pastel2');

# %%
data.Horsepower.plot.box();

# %%
data.Horsepower.plot.box(figsize=(6,3),cmap='Oranges');

# %%
data.plot.box(figsize=(22,4),subplots=True);

# %%
data.plot.hist(figsize=(10,14),subplots=True)
;
# Out:
# ''

# %%
data.sort_values(by='year_resale_value').plot.line('year_resale_value','Price_in_thousands',figsize=(6,3),cmap='flag_r');

# %%
data.sort_values(by='year_resale_value').plot.line('year_resale_value','Price_in_thousands',figsize=(6,3));

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(6,3));

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(10,3),cmap="copper");

# %%
data.sort_values(by='Price_in_thousands')[:10].plot.bar('Manufacturer','Price_in_thousands',figsize=(9,5));

# %%
data.plot.area('Manufacturer','Price_in_thousands');

# %%
data.plot.area('Manufacturer','Price_in_thousands',figsize=(7,4),cmap='spring');

# %%
data.sort_values(by="Price_in_thousands")[:10].plot.barh('Model','Power_perf_factor',figsize=(9,3),cmap='twilight_shifted_r');

# %%
data.sort_values(by='Price_in_thousands')[:6].plot.scatter('Latest_Launch','Price_in_thousands',figsize=(9,3),cmap='nipy_spectral');

# %%
data.plot.box(figsize=(22,8));

# %%
data.sort_values(by="Engine_size",ascending=False)[:10].Engine_size.plot.pie();

# %%
data.plot.kde(figsize=(10,5));

# %%
data.plot.kde(figsize=(20,15),subplots=True);

# %%
data.plot.hexbin('Curb_weight','Fuel_capacity',gridsize=15,cmap='CMRmap');

# %%
data.plot.hexbin('Engine_size','Fuel_capacity',gridsize=12);

# %%
data.Curb_weight.plot.kde();

# %%
data.Sales_in_thousands.plot.kde(figsize=(6,3),cmap='viridis');

# %%
data.plot.hist(figsize=(10,10),subplots=True);

# %%
data.plot.kde(figsize=(10,16),subplots=True);

# %%
data.sort_values(by='Sales_in_thousands')
# Out:
#     Manufacturer          Model  Sales_in_thousands  year_resale_value  \
# 83    Mitsubishi         3000GT               0.110             20.940
# 39         Dodge          Viper               0.916             58.470
# 108   Oldsmobile        Cutlass               1.112             11.240
# 125      Porsche  Carrera Coupe               1.280             60.625
# 6           Audi             A8               1.380             39.000
# ..           ...            ...                 ...                ...
# 58         Honda         Accord             230.902             13.210
# 49          Ford         Taurus             245.815             10.055
# 137       Toyota          Camry             247.994             13.245
# 52          Ford       Explorer             276.747             16.640
# 56          Ford       F-Series             540.561             15.075
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.sort_values(by="Sales_in_thousands").plot.line("Sales_in_thousands","Fuel_capacity",figsize=(9,3),cmap='winter');

# %%
data.sort_values(by='Price_in_thousands')[:10].plot.bar('Manufacturer',figsize=(10,6),legend=True);

# %%
data.plot.area('Model','Sales_in_thousands',figsize=(9,3));

# %%
data.plot.barh('Model','Sales_in_thousands',figsize=(10,20));

# %%
data.plot.scatter('Sales_in_thousands','year_resale_value',figsize=(9,3));

# %%
data.sort_values(by="Sales_in_thousands")
# Out:
#     Manufacturer          Model  Sales_in_thousands  year_resale_value  \
# 83    Mitsubishi         3000GT               0.110             20.940
# 39         Dodge          Viper               0.916             58.470
# 108   Oldsmobile        Cutlass               1.112             11.240
# 125      Porsche  Carrera Coupe               1.280             60.625
# 6           Audi             A8               1.380             39.000
# ..           ...            ...                 ...                ...
# 58         Honda         Accord             230.902             13.210
# 49          Ford         Taurus             245.815             10.055
# 137       Toyota          Camry             247.994             13.245
# 52          Ford       Explorer             276.747             16.640
# 56          Ford       F-Series             540.561             15.075
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.sort_values(by="Sales_in_thousands")[:10].Sales_in_thousands.plot.pie();

# %%
data.sort_values(by='Vehicle_type')
# Out:
#     Manufacturer           Model  Sales_in_thousands  year_resale_value  \
# 69          Jeep  Grand Cherokee             157.040             18.810
# 105       Nissan      Pathfinder              42.574             17.810
# 104       Nissan           Quest              27.308             15.380
# 41         Dodge       Ram Wagon              16.767             15.510
# 42         Dodge         Ram Van              31.038             13.425
# ..           ...             ...                 ...                ...
# 36         Dodge         Avenger               4.734             12.545
# 35         Dodge            Neon              76.034              7.750
# 32      Chrysler             LHS              13.462             17.325
# 57         Honda           Civic             199.685              9.850
# 149   Volkswagen             GTI               5.596             13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.Vehicle_type.value_counts().plot.pie();

# %%
data.Sales_in_thousands.plot.hist(figsize=(9,2),cmap='brg_r');

# %%
data.sort_values(by='Sales_in_thousands')[:10].plot.bar('Manufacturer','Sales_in_thousands',figsize=(9,4));

# %%
data.plot.area('Manufacturer','Sales_in_thousands',figsize=(9,3),cmap='magma');

# %%
data[:10].plot.barh('Model','Sales_in_thousands',figsize=(10,4),cmap='YlGn_r');

# %%
data[:7].plot.scatter('Model','Sales_in_thousands',figsize=(10,4));

# %%
data.sort_values(by='Sales_in_thousands')[:10].plot.scatter('Model','Sales_in_thousands',figsize=(10,4));

# %%
data.plot.box(figsize=(10,4));

# %%
data[:10].Sales_in_thousands.plot.pie();

# %%
data.Model[:11].value_counts().plot.pie();

# %%
data.plot.kde(figsize=(9,2));

# %%
data.Length.plot.kde(figsize=(9,3));

# %%
data.plot.hexbin('Sales_in_thousands','Length',gridsize=5);
